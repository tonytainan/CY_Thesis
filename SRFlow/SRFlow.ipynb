# %%
#Colab資料夾設定方法
#!pip install google.colab #如未安裝取消註解後執行
import os

from google.colab import drive
drive.mount('/content/drive')

##出現提示欄進行授權
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/SRFlow')
os.listdir()

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 97 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 48 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 145 kB 70.0 MB/s
# ...
#      |████████████████████████████████| 156 kB 95.6 MB/s
# ...
#      |████████████████████████████████| 401 kB 77.2 MB/s
# ...
#      |████████████████████████████████| 829 kB 67.6 MB/s
# ...
#      |████████████████████████████████| 784 kB 25.7 MB/s
# ...
#      |████████████████████████████████| 121 kB 92.4 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 52.0 MB/s
# ...
#      |████████████████████████████████| 125 kB 93.0 MB/s
# ...
#      |████████████████████████████████| 56 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 108 kB 87.3 MB/s
# ...
#      |████████████████████████████████| 83 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 84.4 MB/s
# ...
#      |████████████████████████████████| 53 kB 3.1 MB/s
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/SRFlow/datasets')
os.listdir()
# Out:
# ['DF2K-tr_X4.pklv4',
#  'DF2K-tr.pklv4',
#  'DF2K-tr_X8.pklv4',
#  'DIV2K-teFullMod8.pklv4',
#  'DIV2K-teFullMod8_X4.pklv4',
#  'DIV2K-teFullMod8_X8.pklv4',
#  'DIV2K-va.pklv4',
#  'DIV2K-va_X4.pklv4',
#  'DIV2K-va_X8.pklv4',
#  'DF2K-tr_1pct.pklv4',
#  'DF2K-tr_X4_1pct.pklv4',
#  'DF2K-tr_X8_1pct.pklv4',
#  'DIV2K-teFullMod8_1pct.pklv4',
#  'DIV2K-teFullMod8_X4_1pct.pklv4',
#  'DIV2K-teFullMod8_X8_1pct.pklv4',
#  'DIV2K-va_1pct.pklv4',
#  'DIV2K-va_X8_1pct.pklv4',
#  'DIV2K-va_X4_1pct.pklv4',
#  'img_celeba_60x60(100pcs)',
#  'img_celeba_480x480(100pcs)',
#  'img_celeba_50x50(100pcs)',
#  'img_celeba_400x400(100pcs)',
#  'img_celeba_45x45(100pcs)',
#  'img_celeba_360x360(100pcs)',
#  'img_celeba_440x440(100pcs)',
#  'img_celeba_55x55(100pcs)',
#  'img_celeba_320x320(100pcs)',
#  'img_celeba_40x40(100pcs)',
#  'img_celeba_280x280(100pcs)',
#  'img_celeba_35x35(100pcs)',
#  'img_celeba_240x240(100pcs)',
#  'img_celeba_30x30(100pcs)',
#  'img_celeba_25x25(100pcs)',
# ...

# %%
# !cp DF2K-tr.pklv4 /content/DF2K-tr.pklv4
# !cp DF2K-tr_X8.pklv4 /content/DF2K-tr_X8.pklv4
# !cp DIV2K-va.pklv4 /content/DIV2K-va.pklv4
# !cp DIV2K-va_X8.pklv4 /content/DIV2K-va_X8.pklv4

# %%
import os
os.chdir('/content/drive/MyDrive/SRFlow')
os.listdir()
# Out:
# ['README.md',
#  'requirements.txt',
#  'run_jupyter.sh',
#  'setup.sh',
#  '.gitignore',
#  'LICENSE',
#  'SRFlow_demo_(file_200004).jpynb',
#  'SRFlow_demo_(file_200263).jpynb',
#  'SRFlow_demo_(file_200001).jpynb',
#  'SRFlow_demo_(file_200355).jpynb',
#  'SRFlow_demo_(file_162844).jpynb',
#  'SRFlow_demo_(file_162861).jpynb',
#  'SRFlow_demo_(file_202503).jpynb',
#  'SRFlow_demo_(file_202159).jpynb',
#  'SRFlow_demo_(insets_x4).jpynb',
#  'SRFlow.ipynb 的副本',
#  'demo_on_pretrained.ipynb',
#  'SRFlow_demo_(file_200003).jpynb',
#  'SRFlow_demo_(gray).jpynb',
#  'SRFlow_train_celebA_tony.ipynb 的副本',
#  'SRFlow_demo_(insets_x8).jpynb',
#  'SRFlow_demo_(file_DIV2k_0846).jpynb',
#  'SRFlow_demo_(file_DIV2k_0892).jpynb',
#  'SRFlow_(CelebA_200355)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(DIV2k_0892)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(CelebA_200003)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(DIV2k_0846)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
# ...

# %%
# !wget --continue http://data.vision.ee.ethz.ch/alugmayr/SRFlow/datasets.zip
# !unzip datasets.zip
# !rm datasets.zip

# %%
import os
os.chdir('/content/drive/MyDrive/SRFlow/code')
os.listdir()
# Out:
# ['test.py',
#  'imresize.py',
#  'Measure.py',
#  'train.py',
#  'prepare_data.py',
#  'demo_on_pretrained.ipynb',
#  'options',
#  'utils',
#  '__pycache__',
#  'models',
#  'data',
#  'confs',
#  'img_align_celeba']

# %%
# !python train.py -opt ./confs/SRFlow_DF2K_8X_tony_test.yml
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 384, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#         )
#       )
#       (76): FlowStep(
#         (actnorm): ActNorm2d()
#         (invconv): InvertibleConv1x1()
#         (affine): CondAffineSeparatedAndCond(
#           (fAffine): Sequential(
#             (0): Conv2d(
#               416, 64, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (1): ReLU()
#             (2): Conv2d(
#               64, 64, kernel_size=[1, 1], stride=[1, 1], padding=[0, 0], bias=False
#               (actnorm): ActNorm2d()
#             )
#             (3): ReLU()
#             (4): Conv2dZeros(64, 192, kernel_size=[3, 3], stride=[1, 1], padding=[1, 1])
#           )
#           (fFeatures): Sequential(
#             (0): Conv2d(
# ...

# %%
# !python train.py -opt ./confs/SRFlow_CelebA_8X.yml    # Faces 8X

# %%
# !CUDA_VISIBLE_DEVICES=-1 python test.py ./confs/SRFlow_DF2K_4X.yml
