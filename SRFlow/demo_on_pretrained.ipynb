# %% [markdown]
# # Apply a trained SRFlow model

# %% [markdown]
# ## Reproduce using our Setup
#
# - Use the ./setup.sh
# - It install the all packages from the requirements.txt
# - If this notebook does not work, copy the code to start it from setup.py
# - The python interpreter should be '../myenv/bin/python3'

# %%
#Colab資料夾設定方法
#!pip install google.colab #如未安裝取消註解後執行
import os

from google.colab import drive
drive.mount('/content/drive')

##出現提示欄進行授權
os.chdir('/content/drive/MyDrive/Colab Notebooks/SR/SRFlow')
os.listdir()
# !pip3 install lpips
os.chdir('/content/drive/MyDrive/Colab Notebooks/SR/SRFlow/code')
os.listdir()

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %% [markdown]
# # Initialize

# %%
import natsort, glob, pickle, torch
from collections import OrderedDict
import numpy as np
import os

import options.options as option
from models import create_model
from imresize import imresize

import Measure

def find_files(wildcard): return natsort.natsorted(glob.glob(wildcard, recursive=True))

from PIL import Image
def imshow(array):
    display(Image.fromarray(array))

from test import load_model, fiFindByWildcard, imread

def pickleRead(path):
    with open(path, 'rb') as f:
        return pickle.load(f)

# %%
# Convert to tensor
def t(array): return torch.Tensor(np.expand_dims(array.transpose([2, 0, 1]), axis=0).astype(np.float32)) / 255

# convert to image
def rgb(t): return (np.clip((t[0] if len(t.shape) == 4 else t).detach().cpu().numpy().transpose([1, 2, 0]), 0, 1) * 255).astype(np.uint8)

# %% [markdown]
# # List model files
#
# If you do not see models here, download them as in `setup.sh`.

# %%
find_files("../pretrained_models/*.pth")
# Out:
# ['../pretrained_models/ESRGAN_DF2K_8X.pth',
#  '../pretrained_models/RRDB_CelebA_8X.pth',
#  '../pretrained_models/RRDB_DF2K_4X.pth',
#  '../pretrained_models/RRDB_DF2K_8X.pth',
#  '../pretrained_models/SRFlow_CelebA_8X.pth',
#  '../pretrained_models/SRFlow_DF2K_4X.pth',
#  '../pretrained_models/SRFlow_DF2K_8X.pth']

# %% [markdown]
# # Configuration files

# %%
find_files("confs/*.yml")
# Out:
# ['confs/RRDB_CelebA_8X.yml',
#  'confs/RRDB_DF2K_4X.yml',
#  'confs/RRDB_DF2K_8X.yml',
#  'confs/SRFlow_CelebA_8X.yml',
#  'confs/SRFlow_DF2K_4X.yml',
#  'confs/SRFlow_DF2K_8X.yml',
#  'confs/SRFlow_Gray_8X.yml',
#  'confs/SRFlow_Insets_4X.yml',
#  'confs/SRFlow_Insets_8X.yml']

# %% [markdown]
# # List dataset directories

# %%
find_files("../datasets/**/")
# Out:
# ['../datasets/',
#  '../datasets/celebA-validation-gt/',
#  '../datasets/celebA-validation-x8/',
#  '../datasets/div2k-validation-modcrop8-gt/',
#  '../datasets/div2k-validation-modcrop8-x4/',
#  '../datasets/div2k-validation-modcrop8-x8/',
#  '../datasets/gray-gt/',
#  '../datasets/gray-x8/',
#  '../datasets/insets-gt/',
#  '../datasets/insets-x4/',
#  '../datasets/insets-x8/',
#  '../datasets/test-gt/',
#  '../datasets/test-x4/']

# %%
conf_path = './confs/SRFlow_DF2K_4X.yml'

# %% [markdown]
# ### Instancieate the Model

# %%
model, opt = load_model(conf_path)
# Out:
# OrderedDict([('manual_seed', 10), ('lr_G', 0.00025), ('weight_decay_G', 0), ('beta1', 0.9), ('beta2', 0.99), ('lr_scheme', 'MultiStepLR'), ('warmup_iter', -1), ('lr_steps_rel', [0.5, 0.75, 0.9, 0.95]), ('lr_gamma', 0.5), ('niter', 200000), ('val_freq', 40000), ('lr_steps', [100000, 150000, 180000, 190000])])

# %% [markdown]
# ### Find the png paths

# %%
lq_paths = fiFindByWildcard(os.path.join(opt['dataroot_LR'], '*.png'))
gt_paths = fiFindByWildcard(os.path.join(opt['dataroot_GT'], '*.png'))
print(lq_paths, gt_paths) # For CelebA we have just 1
# Out:
# ['../datasets/div2k-validation-modcrop8-x4/0801.png', '../datasets/div2k-validation-modcrop8-x4/0802.png', '../datasets/div2k-validation-modcrop8-x4/0803.png', '../datasets/div2k-validation-modcrop8-x4/0804.png', '../datasets/div2k-validation-modcrop8-x4/0805.png', '../datasets/div2k-validation-modcrop8-x4/0806.png', '../datasets/div2k-validation-modcrop8-x4/0807.png', '../datasets/div2k-validation-modcrop8-x4/0808.png', '../datasets/div2k-validation-modcrop8-x4/0809.png', '../datasets/div2k-validation-modcrop8-x4/0810.png', '../datasets/div2k-validation-modcrop8-x4/0811.png', '../datasets/div2k-validation-modcrop8-x4/0812.png', '../datasets/div2k-validation-modcrop8-x4/0813.png', '../datasets/div2k-validation-modcrop8-x4/0814.png', '../datasets/div2k-validation-modcrop8-x4/0815.png', '../datasets/div2k-validation-modcrop8-x4/0816.png', '../datasets/div2k-validation-modcrop8-x4/0817.png', '../datasets/div2k-validation-modcrop8-x4/0818.png', '../datasets/div2k-validation-modcrop8-x4/0819.png', '../datasets/div2k-validation-modcrop8-x4/0820.png', '../datasets/div2k-validation-modcrop8-x4/0821.png', '../datasets/div2k-validation-modcrop8-x4/0822.png', '../datasets/div2k-validation-modcrop8-x4/0823.png', '../datasets/div2k-validation-modcrop8-x4/0824.png', '../datasets/div2k-validation-modcrop8-x4/0825.png', '../datasets/div2k-validation-modcrop8-x4/0826.png', '../datasets/div2k-validation-modcrop8-x4/0827.png', '../datasets/div2k-validation-modcrop8-x4/0828.png', '../datasets/div2k-validation-modcrop8-x4/0829.png', '../datasets/div2k-validation-modcrop8-x4/0830.png', '../datasets/div2k-validation-modcrop8-x4/0831.png', '../datasets/div2k-validation-modcrop8-x4/0832.png', '../datasets/div2k-validation-modcrop8-x4/0833.png', '../datasets/div2k-validation-modcrop8-x4/0834.png', '../datasets/div2k-validation-modcrop8-x4/0835.png', '../datasets/div2k-validation-modcrop8-x4/0836.png', '../datasets/div2k-validation-modcrop8-x4/0837.png', '../datasets/div2k-validation-modcrop8-x4/0838.png', '../datasets/div2k-validation-modcrop8-x4/0839.png', '../datasets/div2k-validation-modcrop8-x4/0840.png', '../datasets/div2k-validation-modcrop8-x4/0841.png', '../datasets/div2k-validation-modcrop8-x4/0842.png', '../datasets/div2k-validation-modcrop8-x4/0843.png', '../datasets/div2k-validation-modcrop8-x4/0844.png', '../datasets/div2k-validation-modcrop8-x4/0845.png', '../datasets/div2k-validation-modcrop8-x4/0846.png', '../datasets/div2k-validation-modcrop8-x4/0847.png', '../datasets/div2k-validation-modcrop8-x4/0848.png', '../datasets/div2k-validation-modcrop8-x4/0849.png', '../datasets/div2k-validation-modcrop8-x4/0850.png', '../datasets/div2k-validation-modcrop8-x4/0851.png', '../datasets/div2k-validation-modcrop8-x4/0852.png', '../datasets/div2k-validation-modcrop8-x4/0853.png', '../datasets/div2k-validation-modcrop8-x4/0854.png', '../datasets/div2k-validation-modcrop8-x4/0855.png', '../datasets/div2k-validation-modcrop8-x4/0856.png', '../datasets/div2k-validation-modcrop8-x4/0857.png', '../datasets/div2k-validation-modcrop8-x4/0858.png', '../datasets/div2k-validation-modcrop8-x4/0859.png', '../datasets/div2k-validation-modcrop8-x4/0860.png', '../datasets/div2k-validation-modcrop8-x4/0861.png', '../datasets/div2k-validation-modcrop8-x4/0862.png', '../datasets/div2k-validation-modcrop8-x4/0863.png', '../datasets/div2k-validation-modcrop8-x4/0864.png', '../datasets/div2k-validation-modcrop8-x4/0865.png', '../datasets/div2k-validation-modcrop8-x4/0866.png', '../datasets/div2k-validation-modcrop8-x4/0867.png', '../datasets/div2k-validation-modcrop8-x4/0868.png', '../datasets/div2k-validation-modcrop8-x4/0869.png', '../datasets/div2k-validation-modcrop8-x4/0870.png', '../datasets/div2k-validation-modcrop8-x4/0871.png', '../datasets/div2k-validation-modcrop8-x4/0872.png', '../datasets/div2k-validation-modcrop8-x4/0873.png', '../datasets/div2k-validation-modcrop8-x4/0874.png', '../datasets/div2k-validation-modcrop8-x4/0875.png', '../datasets/div2k-valid ...

# %%
lqs = [imread(p) for p in lq_paths]
gts = [imread(p) for p in gt_paths]

# %%
print("First LR image")
imshow(lqs[7])

print("First HR image")
imshow(gts[7])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Super-Resolve using SRFlow for multiple temperatures

# %%
measure = Measure.Measure()
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.7/dist-packages/lpips/weights/v0.1/alex.pth

# %%
lq = lqs[7]
gt = gts[7]

for temperature in np.linspace(0, 1, num=11):
    # Sample a super-resolution for a low-resolution image
    sr = rgb(model.get_sr(lq=t(lq), heat=temperature))
    imshow(sr)
    psnr, ssim, lpips = measure.measure(sr, gt)
    print('Temperature: {:0.2f} - PSNR: {:0.1f}, SSIM: {:0.1f}, LPIPS: {:0.2f}\n\n'.format(temperature, psnr, ssim, lpips))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # LR Consistency

# %%
lq = lqs[0]
gt = gts[0]

temperature = 0.9

downsampled = lq
for idx in range(5):
    sr = rgb(model.get_sr(lq=t(downsampled), heat=temperature))
    downsampled = imresize(sr, 1/8)
    
    imshow(sr)
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7FFDCE0BCA90>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7FFDCE0BCA90>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7FFDC5ABE2D0>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7FFDC7E37390>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7FFDC5ABE2D0>
