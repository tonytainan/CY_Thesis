# %%
#Colab資料夾設定方法
#!pip install google.colab #如未安裝取消註解後執行
import os

from google.colab import drive
drive.mount('/content/drive')

##出現提示欄進行授權
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/SRFlow')
os.listdir()
# Out:
# ['README.md',
#  'requirements.txt',
#  'run_jupyter.sh',
#  'setup.sh',
#  '.gitignore',
#  'LICENSE',
#  'SRFlow_demo_(file_200004).jpynb',
#  'SRFlow_demo_(file_200263).jpynb',
#  'SRFlow_demo_(file_200001).jpynb',
#  'SRFlow_demo_(file_200355).jpynb',
#  'SRFlow_demo_(file_162844).jpynb',
#  'SRFlow_demo_(file_162861).jpynb',
#  'SRFlow_demo_(file_202503).jpynb',
#  'SRFlow_demo_(file_202159).jpynb',
#  'SRFlow_demo_(insets_x4).jpynb',
#  'SRFlow.ipynb 的副本',
#  'demo_on_pretrained.ipynb',
#  'SRFlow_demo_(file_200003).jpynb',
#  'SRFlow_demo_(gray).jpynb',
#  'SRFlow_train_celebA_tony.ipynb 的副本',
#  'SRFlow_demo_(insets_x8).jpynb',
#  'SRFlow_demo_(file_DIV2k_0846).jpynb',
#  'SRFlow_demo_(file_DIV2k_0892).jpynb',
#  'SRFlow_(CelebA_200355)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(DIV2k_0892)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(CelebA_200003)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(DIV2k_0846)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
# ...

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 97 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 48 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 145 kB 93.2 MB/s
# ...
#      |████████████████████████████████| 156 kB 62.7 MB/s
# ...
#      |████████████████████████████████| 401 kB 95.1 MB/s
# ...
#      |████████████████████████████████| 829 kB 71.6 MB/s
# ...
#      |████████████████████████████████| 784 kB 68.4 MB/s
# ...
#      |████████████████████████████████| 121 kB 70.5 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 63.3 MB/s
# ...
#      |████████████████████████████████| 125 kB 72.2 MB/s
# ...
#      |████████████████████████████████| 56 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 108 kB 93.0 MB/s
# ...
#      |████████████████████████████████| 83 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 83.4 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.7 MB/s
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/SRFlow')
os.listdir()
# Out:
# ['README.md',
#  'requirements.txt',
#  'run_jupyter.sh',
#  'setup.sh',
#  '.gitignore',
#  'LICENSE',
#  'SRFlow_demo_(file_200004).jpynb',
#  'SRFlow_demo_(file_200263).jpynb',
#  'SRFlow_demo_(file_200001).jpynb',
#  'SRFlow_demo_(file_200355).jpynb',
#  'SRFlow_demo_(file_162844).jpynb',
#  'SRFlow_demo_(file_162861).jpynb',
#  'SRFlow_demo_(file_202503).jpynb',
#  'SRFlow_demo_(file_202159).jpynb',
#  'SRFlow_demo_(insets_x4).jpynb',
#  'SRFlow.ipynb 的副本',
#  'demo_on_pretrained.ipynb',
#  'SRFlow_demo_(file_200003).jpynb',
#  'SRFlow_demo_(gray).jpynb',
#  'SRFlow_train_celebA_tony.ipynb 的副本',
#  'SRFlow_demo_(insets_x8).jpynb',
#  'SRFlow_demo_(file_DIV2k_0846).jpynb',
#  'SRFlow_demo_(file_DIV2k_0892).jpynb',
#  'SRFlow_(CelebA_200355)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(DIV2k_0892)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(CelebA_200003)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
#  'SRFlow_(DIV2k_0846)_Bicubic_x8_LR_PSNR_SSIM(Tony).jpynb',
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/SRFlow/code')
os.listdir()
# Out:
# ['test.py',
#  'imresize.py',
#  'Measure.py',
#  'train.py',
#  'prepare_data.py',
#  'demo_on_pretrained.ipynb',
#  'options',
#  'utils',
#  '__pycache__',
#  'models',
#  'data',
#  'confs',
#  'img_align_celeba']

# %%
# !unzip '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_1.zip' -d '/content/drive/MyDrive/SRFlow/datasets/'
# Out:
# Archive:  /content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_1.zip

# %%
# !python prepare_data.py '/content/drive/MyDrive/SRFlow/datasets/img_celeba_160_1'
# Out:
#   0% 0/6060 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "prepare_data.py", line 120, in <module>
#     main(dir_path)
#   File "prepare_data.py", line 81, in main
#     crop = random_crop(img, 160)
#   File "prepare_data.py", line 50, in random_crop
#     h_start = np.random.randint(0, h - size)
#   File "mtrand.pyx", line 746, in numpy.random.mtrand.RandomState.randint
#   File "_bounded_integers.pyx", line 1254, in numpy.random._bounded_integers._rand_int64
# ValueError: low >= high

# %%
# !CUDA_VISIBLE_DEVICES=-1 python test.py ./confs/SRFlow_DF2K_4X.yml
