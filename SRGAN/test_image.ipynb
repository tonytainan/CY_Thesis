# %%
print("============查看GPU信息================")
# 查看GPU信息
# !/opt/bin/nvidia-smi
print("==============查看pytorch版本==============")
# 查看pytorch版本
import torch
print(torch.__version__)
print("============查看虚拟机硬盘容量================")
# 查看虚拟机硬盘容量
# !df -lh
print("============查看cpu配置================")
# 查看cpu配置
# !cat /proc/cpuinfo | grep model\ name
print("=============查看内存容量===============")
# 查看内存容量
# !cat /proc/meminfo | grep MemTotal

# %%
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/SRGAN(leftthomas)')
os.listdir() #確認目錄內容

# %%
# !pip3 install lpips
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python test_image.py --upscale_factor 8 --image_name 200001.png --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name 200004.png --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name 200355.png --gt_image_name 200355_hr.png --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name 200003.png --gt_image_name 200003_gt.png --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name 200263.png --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name 202159.png --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name 202503.png --model_name netG_epoch_8_100.pth

# %% [markdown]
# set14, butterfly x8

# %%
# !python test_image.py --upscale_factor 8 --image_name 'img_011_LR_cropped(54x54).png' --gt_image_name 'img_011_HR_cropped(432x432).png' --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name gray_face_lr_20x20.png --gt_image_name gray_sr_160x160.png --model_name netG_epoch_8_100.pth
# Out:
# test_image.py:41: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   image = Variable(ToTensor()(image), volatile=True).unsqueeze(0)
# test_image.py:45: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   start = time.clock()
# test_image.py:47: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   elapsed = (time.clock() - start)
# cost1.3071890000000006s
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   "Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. "
# ...

# %%
# !python test_image.py --upscale_factor 8 --image_name 0002_lr_200x200.png --gt_image_name 0002_hr_1600x1600.png --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name 0892_lr_200x200.png --gt_image_name 0892_hr_1600x1600.png --model_name netG_epoch_8_100.pth

# %%
# !python test_image.py --upscale_factor 8 --image_name 0846_lr_200x200.png --gt_image_name 0846_hr_1600x1600.png --model_name netG_epoch_8_100.pth
# Out:
# test_image.py:41: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   image = Variable(ToTensor()(image), volatile=True).unsqueeze(0)
# test_image.py:45: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   start = time.clock()
# test_image.py:47: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   elapsed = (time.clock() - start)
# cost0.053925999999999696s
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# ...
