# %%
print("============查看GPU信息================")
# 查看GPU信息
# !/opt/bin/nvidia-smi
print("==============查看pytorch版本==============")
# 查看pytorch版本
import torch
print(torch.__version__)
print("============查看虚拟机硬盘容量================")
# 查看虚拟机硬盘容量
# !df -lh
print("============查看cpu配置================")
# 查看cpu配置
# !cat /proc/cpuinfo | grep model\ name
print("=============查看内存容量===============")
# 查看内存容量
# !cat /proc/meminfo | grep MemTotal

# %%
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/SRGAN(leftthomas)')
os.listdir() #確認目錄內容

# %%
os.chdir('/content/drive/MyDrive/data')
os.listdir() #確認目錄內容
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip


#!wget --continue http://data.vision.ee.ethz.ch/alugmayr/SRFlow/datasets.zip
#!unzip datasets.zip
#!rm datasets.zip

# %%
# !mkdir '/content/data'
# !cp '/content/drive/MyDrive/data/DIV2K_train_HR.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/DIV2K_valid_HR.zip' '/content/data/'
# Out:
# mkdir: cannot create directory ‘/content/data’: File exists

# %%
os.chdir('/content/data')
os.listdir() #確認目錄內容 
# !unzip -j DIV2K_train_HR.zip -d train
# !unzip -j DIV2K_valid_HR.zip -d valid
# Out:
# Archive:  DIV2K_train_HR.zip
# replace train/0103.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: train/0103.png
#   inflating: train/0413.png
#   inflating: train/0031.png
#   inflating: train/0660.png
#   inflating: train/0126.png
#   inflating: train/0793.png
#   inflating: train/0764.png
#   inflating: train/0550.png
#   inflating: train/0437.png
#   inflating: train/0374.png
#   inflating: train/0755.png
#   inflating: train/0614.png
#   inflating: train/0646.png
#   inflating: train/0371.png
#   inflating: train/0312.png
#   inflating: train/0108.png
#   inflating: train/0556.png
#   inflating: train/0794.png
#   inflating: train/0722.png
#   inflating: train/0780.png
#   inflating: train/0555.png
#   inflating: train/0439.png
#   inflating: train/0396.png
#   inflating: train/0666.png
#   inflating: train/0254.png
#   inflating: train/0344.png
#   inflating: train/0062.png
#   inflating: train/0657.png
#   inflating: train/0117.png
#   inflating: train/0395.png
# ...

# %%
# !mkdir '/content/data'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_1.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_2.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_3.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_4.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_5.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_6.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_7.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_8.zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_9(162770).zip' '/content/data/'
# !cp '/content/drive/MyDrive/data/img_celeba_160x160/img_celeba_160_9(162771-162870).zip' '/content/data/'

# %%
os.chdir('/content/data')
os.listdir() #確認目錄內容
# Out:
# ['img_celeba_160_5.zip',
#  'img_celeba_160_7.zip',
#  'img_celeba_160_8.zip',
#  'img_celeba_160_6.zip',
#  'img_celeba_160_9(162771-162870).zip',
#  'img_celeba_160_2.zip',
#  'img_celeba_160_3.zip',
#  'img_celeba_160_1.zip',
#  'img_celeba_160_4.zip',
#  'img_celeba_160_9(162770).zip']

# %%
# !unzip -j img_celeba_160_1.zip -d train
# !unzip -j img_celeba_160_2.zip -d train
# !unzip -j img_celeba_160_3.zip -d train
# !unzip -j img_celeba_160_4.zip -d train
# !unzip -j img_celeba_160_5.zip -d train
# !unzip -j img_celeba_160_6.zip -d train
# !unzip -j img_celeba_160_7.zip -d train
# !unzip -j img_celeba_160_8.zip -d train
# !unzip -j 'img_celeba_160_9(162770).zip' -d train
# !unzip -j 'img_celeba_160_9(162771-162870).zip' -d valid

# %%
# !rm *.zip

# %%
os.chdir('/content/drive/MyDrive/SRGAN(leftthomas)')
os.listdir() #確認目錄內容
# Out:
# ['LICENSE',
#  'model.py',
#  'loss.py',
#  'test_video.py',
#  'README.md',
#  'test_benchmark.py',
#  'data_utils.py',
#  'training_results',
#  '__pycache__',
#  'benchmark_results',
#  'pytorch_ssim',
#  'data',
#  'images',
#  'statistics',
#  'epochs_backup',
#  'epochs',
#  '200003.png',
#  '200004.png',
#  '200001.png',
#  '200355.png',
#  '200263.png',
#  '202159.png',
#  '202503.png',
#  'train.py',
#  'out_srf_8_200001.png',
#  'out_lr_8_200001.png',
#  'out_srf_8_200003.png',
#  'out_lr_8_200003.png',
#  'out_srf_8_200355.png',
#  'out_lr_8_200355.png',
#  'out_srf_8_200263.png',
#  'out_lr_8_200263.png',
#  'out_srf_8_200004.png',
#  'out_lr_8_200004.png',
#  'out_srf_8_202159.png',
#  'out_lr_8_202159.png',
#  'sight.png',
#  'out_srf_8_202503.png',
#  'out_lr_8_202503.png',
#  'butterfly_lr_20x20.png',
#  'out_srf_8_butterfly_lr_20x20.png',
#  'out_lr_8_butterfly_lr_20x20.png',
#  'gray_face_lr_20x20.png',
#  'out_srf_8_gray_face_lr_20x20.png',
# ...

# %%
# !python train.py
